# %%
import pandas as pd

# %%
# pip install xlrd
# pip install openpyxl

# %%
xlsfile = pd.ExcelFile('E:/excel udemy/1.+PivotTable.xlsx')

# %%
dframe = xlsfile.parse('Pivot')
# dframe = xlsfile.parse('Sheet1')

# %%
dframe
# Out:
#      ID    Last name First name Region      Designation Date of Birth  \
# 0   101        Davis       Sara   East       Sales Rep.    1968-08-12
# 1   102      Fontana    Olivier  North    V.P. of Sales    1968-02-19
# 2   103         Leal     Karina  North       Sales Rep.    1963-08-30
# 3   104       Patten    Michael   West       Sales Rep.    1958-09-19
# 4   105        Burke      Brian   West       Sales Mgr.    1955-04-03
# 5   106        Sousa       Luis  South       Sales Rep.    1963-02-07
# 6   107         John      Smith   East      Sales Exec.    1968-08-07
# 7   108        Jones      David   West      Sales Exec.    1969-09-22
# 8   109      Johnson    Michael  North      Sales Exec.    1979-09-24
# 9   110          Lee      Chris   East       Sales Rep.    1976-03-15
# 10  111        Brown       Mike   West       Sales Rep.    1976-04-25
# 11  112     Williams       Mark  North       Sales Rep.    1975-07-14
# ...
